# %% [markdown]
# Problem Formulation
# - We discussed that PCA reduces the higher dimensional data into lower dimensional data in terms of column. What it does is it reduces the higher number of column in to lower column.Kunai feature haru ko wa dherai feature haru ko basis ma chai euta naya feature form garne which can replicate both the features.It is one of the process of feature extraction.

# %% [markdown]
# What PCA solves mathematically?
# -
