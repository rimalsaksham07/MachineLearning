# %% [markdown]
# How to find m and b?
# - Input = cgpa
# - Output = placement

# %% [markdown]
# So , now first we draw a straight line passing very close to all the point which is the best fit such that error is very minimum.

# %% [markdown]
# Closed form solution - kunai pani operaion ko solution banauna sakinxa bhane it is closed form solution aba hamle quadtratic equation ma rakhera x , y ko value nikalna milxa bhane closed form approximater method haru use garera garne lai open form solution.(Gradient Descent).Two different different solution hunxa direct formula use garne or Gradient Descent use garera aprroximate garne. Higher dimension ma formula use garna garo hunxa So higher dimension use huda chai gradient descent use garne ni hunxa.

# %% [markdown]
# y = mx + c

# %% [markdown]
# b = y - mx

# %% [markdown]
# m = (xi - xmean)(yi - ymean) / (xi - xmean) ^ 2

# %% [markdown]
# Create the best fit line such that the point and line distance is very minimum so for each point there will be error to and we have to find such line which minimizes the error.

# %% [markdown]
# distance (di) = actual(yi) - predicted(yi)

# %% [markdown]
# Cost Function (E) = sum (di ^2 )

# %% [markdown]
# Cost Function (E) = sum( ( actual - predicted) ^ 2 )

# %% [markdown]
# So now what cost function does is it is used to minimize the error

# %% [markdown]
# y(predicted ) = mxi + b

# %% [markdown]
# so now , E (m,b) = sum((yi - mxi - b)^2)

# %% [markdown]
# Now we find m and b such that E(m,b) will be very minimum
# y = f(x)

# %% [markdown]
# So finally,

# %% [markdown]
# #### b = (y-mean) - m (x mean)
# #### m = ((xi - xmean)(yi - ymean)) / (xi - xmean) ^2

# %%
class MyLr:
    def __init__(self):
        self.m = None
        self.b = None
    def fit(self, X_train , Y_train):
        num = 0 
        den = 0 
        for i in range(X_train.shape[0]):
            num = num + (X_train[i] - X_train.mean()) * (y_train[i] - y_train.mean())
            den = den + ((X_train[i] - X_train.mean()) *(X_train[i] - X_train.mean()))

        self.m = num / den 
        self.b = y_train.mean() - 
            
    def predict(self , X_test):
        pass

# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
X = df.iloc[:, 0].values
y = df.iloc[: ,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2)

# %%
X_train.shape
# Out:
# (160,)

# %%
lr = MyLr()

# %%
lr.fit(X_train, y_train)
# Out:
# (160,)

# %%
X_train[0].mean()
# Out:
# 7.35
